# %%
import pandas as pd

masterfile_final_columns = pd.read_csv("columns_to_keep/masterfile_final_columns.csv", dtype="string")["column_names"].tolist()

state = pd.read_csv("csv_outputs/merge_state_df_2026-01-10.csv", dtype="string")

messy = pd.read_csv("csv_outputs/merge_messy_work_df_2026-01-14.csv", dtype="string")

www_columns = pd.read_csv("columns_to_keep/www_columns.csv")
www = pd.read_csv('raw_data_messy/home&work/www.csv', dtype="string")[www_columns["column_names"].tolist()]
www.columns = www.columns.str.upper()

combined_masterfile_2_1_columns = pd.read_csv("columns_to_keep/masterfile_2_1_columns.csv")
combined_masterfile_2_1 = pd.read_csv('raw_data_messy/home&work/Combined Master File 2_1.csv', dtype="string")[combined_masterfile_2_1_columns["column_names"].tolist()]
combined_masterfile_2_1.columns = combined_masterfile_2_1.columns.str.upper()

# %%
messy_renamed = messy.copy()
messy_renamed_mapping_dict = {
    'SOURCEFILE': "source_file",
    'FIRSTNAME': "first_name",
    'LASTNAME': "last_name",
    'JOBTITLE': "job_title",
    'EMAIL': "email",
    'WORKPHONENUMBER': "work_phone",
    'COMPANYLINKEDIN': "company_linkedin",
    'FACEBOOK': "facebook",
    'COMPANYTWITTER': "twitter",
    'INDUSTRY': "industry",
    'COMPANYNAME': "company_name",
    'WEBSITE': "company_website",
    'COMPANYADDRESS': "company_address",
    'COMPANYZIPCODE': "company_zipcode",
    'EMPLOYEECOUNT': "company_employee_size_actual",
    'COMPANYCITY': "company_city",
    'COMPANYSTATE': "company_state",
    'COMPANYCOUNTRY': "DELETECOLUMN",
    'COMPANYREVENUE': "company_revenue",
    'COMPANYLOCATION': "company_location",
    'COMPANYFOUNDEDAT': "company_founded_at",
    'COMPANYREVENUERANGE': "DELETECOLUMN",
    "LATESTFUNDINGSTAGE": "DELETECOLUMN",
    "COMPANYFUNDING": "DELETECOLUMN",
    "MOBILEPHONE": "mobile_phone"
}
messy_renamed = messy.rename(columns=messy_renamed_mapping_dict, errors="raise")
messy_renamed = messy_renamed.drop(columns=["DELETECOLUMN"])
for column in messy_renamed.columns:
    if column not in masterfile_final_columns:
        print(f"Warning: Column {column} is not in masterfile_final_columns.csv")

# %%
state_renamed = state.copy()
state_renamed_mapping_dict = {
    "SOURCEFILE": "source_file",
    'Company Name': "company_name",
    'Executive First Name': "first_name",
    'Executive Last Name': "last_name",
    'Executive Title': "job_title",
    'Executive Gender': "gender",
    'Address': "company_address",
    'City': "company_city",
    'State': "company_state",
    'ZIP Code': "company_zipcode",
    'ZIP Four': "company_zipfour",
    'County': "county",
    'Phone Number Combined': "work_phone",
    'Website': "company_website",
    'Company Description': "company_description",
    'Primary SIC Code': "primary_sic_code",
    'Primary SIC Description': "primary_sic_code_description",
    'Primary NAICS': "primary_naics",
    'Primary NAICS Description': "primary_naics_description",
    'Cuisine Code': "cuisine_code",
    'Cuisine Code Description': "cuisine_code_description",
    'Location Sales Volume Range': "location_sales_volume_range",
    'Location Sales Volume Actual': "location_sales_volume_actual",
    'Location Employee Size Range': "company_employee_size_range",
    'Location Employee Size Actual': "company_employee_size_actual",
    'Corporate Sales Volume Range': "company_sales_volume_range",
    'Corporate Sales Volume Actual': "company_sales_volume_actual",
    'Type of Business': "business_type",
    'Credit Cards Accepted': "credit_cards_accepted",
    'Twitter': "twitter",
    'Linked-In': "company_linkedin",
    'Facebook': "facebook",
}
state_renamed = state.rename(columns=state_renamed_mapping_dict, errors="raise")
state_renamed = state_renamed[list(state_renamed_mapping_dict.values())]

for column in state_renamed.columns:
    if column not in masterfile_final_columns:
        print(f"Warning: Column {column} is not in masterfile_final_columns.csv")

# %%
www_renamed = www.copy()

www_renamed_mapping_dict = {
    'FIRST NAME': 'first_name',
    'LAST NAME': 'last_name',
    'TITLE': 'job_title',
    'COMPANY NAME FOR EMAILS': 'company_name',
    '# EMPLOYEES': 'company_employee_size_actual',
    'PERSON LINKEDIN URL': 'linkedin',
    'WEBSITE': 'company_website',
    'COMPANY LINKEDIN URL': 'company_linkedin',
    'FACEBOOK URL': 'facebook',
    'TWITTER URL': 'twitter',
    'EMAIL': 'email',
    'CORPORATE PHONE': 'work_phone',
    'VOTERTELEPHONES_CELLPHONEUNFORMATTED': 'mobile_phone',
    'VOTERTELEPHONES_LANDLINEUNFORMATTED': 'landline_phone',
    'COMPANY ADDRESS': 'company_address',
    'COMPANY CITY': 'company_city',
    'COMPANY STATE': 'company_state',
    'ZIPCODE': 'company_zipcode',
    'RESIDENCE_ADDRESSES_ADDRESSLINE': 'home_address',
    'CITY': 'home_city',
    'RESIDENCE_ADDRESSES_STATE': 'home_state',
    'RESIDENCE_ADDRESSES_ZIP': 'home_zipcode',
    'COUNTY': 'county',
    'VOTERS_STATEVOTERID': 'state_voter_id',
    'VOTERS_GENDER': 'gender',
    'VOTERS_AGE': 'age',
    'VOTERS_AGERANGE': 'age_range',
    'PARTIES_DESCRIPTION': 'party_description',
    'ETHNICGROUPS_ETHNICGROUP1DESC': 'ethnic_group',
    'US_CONGRESSIONAL_DISTRICT': 'us_congressional_district',
    'STATE_SENATE_DISTRICT': 'state_senate_district',
    'STATE_LEGISLATIVE_DISTRICT': 'state_legislative_district',
    'STATE_HOUSE_DISTRICT': 'state_house_district',
    'PRECINCT': 'precinct',
    'COUNTY_COMMISSIONER_DISTRICT': 'county_commissioner_district',
    'COUNTY_SUPERVISORIAL_DISTRICT': 'county_supervisorial_district',
    'CONSUMERDATA_LANGUAGE_CODE': 'language_code',
    'CONSUMERDATA_MARITAL_STATUS': 'marital_status',
    'CONSUMERDATA_RELIGION_CODE': 'religion_code',
    'CONSUMERDATA_PRESENCE_OF_CHILDREN_IN_HH': 'presence_of_children_in_household',
    'CONSUMERDATA_CRA_INCOME_CLASSIFICATION_CODE': 'DELETECOLUMN',
    'CONSUMERDATA_HOUSEHOLD_NET_WORTH': 'household_net_worth',
    'CONSUMERDATA_VETERAN_IN_HH': 'veteran_in_household',
    'VOTERS_VOTINGPERFORMANCEEVENYEARGENERAL': 'voting_performance_even_year_general',
    'VOTERS_VOTINGPERFORMANCEEVENYEARPRIMARY': 'voting_performance_even_year_primary',
    'VOTERS_VOTINGPERFORMANCEEVENYEARGENERALANDPRIMARY': 'voting_performance_even_year_general_and_primary',
    'VOTERS_VOTINGPERFORMANCEMINORELECTION': 'voting_performance_minor_election',
    'PRIMARY_NOF4': 'primary_n_of_4',
    'GENERAL_2024': 'general_2024',
    'PRIMARY_2024': 'primary_2024',
    'GENERAL_2022': 'general_2022',
    'PRIMARY_2022': 'primary_2022',
    'GENERAL_2020': 'general_2020',
    'PRIMARY_2020': 'primary_2020'
}
www_renamed.insert(0, "source_file", "www.csv")
www_renamed = www_renamed.rename(columns=www_renamed_mapping_dict, errors="raise")
www_renamed = www_renamed.drop(columns=["DELETECOLUMN"])
for column in www_renamed.columns:
    if column not in masterfile_final_columns:
        print(f"Warning: Column {column} is not in masterfile_final_columns.csv")

# %%
combined_masterfile_2_1_renamed = combined_masterfile_2_1.copy()

rename_fill_order_dict = {
    'first_name': ['A.FIRST_NAME', 'A.VOTERS_FIRSTNAME', 'B.FIRST_NAME',],
    'last_name': [ 'A.LAST_NAME', 'A.VOTERS_LASTNAME', 'B.LAST_NAME',],    
    'job_title': [ 'B.TITLE',],
    'company_name': [ 'B.COMPANY', 'B.COMPANY_NAME_FOR_EMAILS',],
    'work_phone': [ 'B.CORPORATE_PHONE', 'B.COMPANY_PHONE'],
    'mobile_phone': [ 'A.MOBILE_PHONE',  'A.VOTERTELEPHONES_CELLPHONEUNFORMATTED', 'B.PERSONAL_PHONE', 'B.PERSONAL_PHONE_2', 'A.PHONE',],
    'email': [ 'B.EMAIL', 'B.EMAIL_1',],
    'company_address': [ 'B.COMPANY_ADDRESS',],
    'company_city': [ 'B.COMPANY_CITY', 'B.CITY'],
    'company_state': [ 'B.COMPANY_STATE', "B.STATE"],
    'company_zipcode': [ 'B.EXTRACTED_ZIP_CODE',],
    'company_zipfour': [],
    'business_type': [],
    'company_website': [ 'B.WEBSITE',],
    'company_linkedin': [ 'B.COMPANY_LINKEDIN_URL',],
    'company_description': [],
    'company_founded_at': [],
    'company_location': [],
    'primary_sic_code': [],
    'primary_sic_code_description': [],
    'primary_naics': [],
    'primary_naics_description': [],
    'location_sales_volume_range': [],
    'location_sales_volume_actual': [],
    'company_employee_size_range': [],
    'company_employee_size_actual': [ 'B.EMPLOYEES',],
    'company_sales_volume_range': [],
    'company_sales_volume_actual': [],
    'company_revenue': [],
    'cuisine_code': [],
    'cuisine_code_description': [],
    'credit_cards_accepted': [],
    'home_address': [ 'A.RESIDENCE_ADDRESSES_ADDRESSLINE',],
    'home_city': [ 'A.CITY'],
    'home_state': [ 'A.RESIDENCE_ADDRESSES_STATE',],
    'home_zipcode': [ 'A.ZIP_CODE', 'A.RESIDENCE_ADDRESSES_ZIP',],
    'home_zipfour': [],
    'landline_phone': [ 'A.VOTERTELEPHONES_LANDLINEUNFORMATTED',],
    'linkedin': [ 'B.PERSON_LINKEDIN_URL',],
    'facebook': [ 'B.FACEBOOK_URL',],
    'twitter': [ 'B.TWITTER_URL',],
    'language_code': [ 'A.CONSUMERDATA_LANGUAGE_CODE',],
    'marital_status': [ 'A.CONSUMERDATA_MARITAL_STATUS',],
    'religion_code': [ 'A.CONSUMERDATA_RELIGION_CODE',],
    'household_net_worth': [],
    'presence_of_children_in_household': [ 'A.CONSUMERDATA_PRESENCE_OF_CHILDREN_IN_HH',],
    'veteran_in_household': [ 'A.CONSUMERDATA_VETERAN_IN_HH',],
    'ethnic_group': [ 'A.ETHNICGROUPS_ETHNICGROUP1DESC',],
    'age': [ 'A.VOTERS_AGE',],
    'age_range': [ 'A.VOTERS_AGERANGE',],
    'gender': [ 'A.VOTERS_GENDER',],
    'party_description': [ 'A.PARTIES_DESCRIPTION',],
    'primary_n_of_4': [ 'A.PRIMARY_NOF4',],
    'general_2024': [ 'A.GENERAL_2024',],
    'primary_2024': [ 'A.PRIMARY_2024',],
    'general_2022': [ 'A.GENERAL_2022',],
    'primary_2022': [ 'A.PRIMARY_2022',],
    'general_2020': [ 'A.GENERAL_2020',],
    'primary_2020': [ 'A.PRIMARY_2020',],
    'voting_performance_minor_election': [ 'A.VOTERS_VOTINGPERFORMANCEMINORELECTION',],
    'voting_performance_even_year_general': [ 'A.VOTERS_VOTINGPERFORMANCEEVENYEARGENERAL',],
    'voting_performance_even_year_primary': [ 'A.VOTERS_VOTINGPERFORMANCEEVENYEARPRIMARY',],
    'voting_performance_even_year_general_and_primary': [ 'A.VOTERS_VOTINGPERFORMANCEEVENYEARGENERALANDPRIMARY',],
    'us_congressional_district': [ 'A.US_CONGRESSIONAL_DISTRICT',],
    'state_senate_district': [ 'A.STATE_SENATE_DISTRICT',],
    'state_house_district': [ 'A.STATE_HOUSE_DISTRICT',],
    'state_legislative_district': [ 'A.STATE_LEGISLATIVE_DISTRICT',],
    'county_commissioner_district': [],
    'county_supervisorial_district': [ 'A.COUNTY_SUPERVISORIAL_DISTRICT',],
    'county': [ 'A.COUNTY',],
    'precinct': [ 'A.PRECINCT',],
    'state_voter_id': [ 'A.VOTERS_STATEVOTERID',],
    'industry': [ 'B.INDUSTRY',]
}
for key, available_columns in rename_fill_order_dict.items():
    if len(available_columns) == 0:
        combined_masterfile_2_1_renamed[key] = None
    else:
        for i in range(len(available_columns)):
            if i == 0:
                combined_masterfile_2_1_renamed[key] = combined_masterfile_2_1_renamed[available_columns[i]]
            else:
                combined_masterfile_2_1_renamed[key] = combined_masterfile_2_1_renamed[key].fillna(combined_masterfile_2_1_renamed[available_columns[i]])

combined_masterfile_2_1_renamed["source_file"] = "Combined Master File 2_1"
combined_masterfile_2_1_renamed = combined_masterfile_2_1_renamed.drop(columns=combined_masterfile_2_1.columns.tolist())

# %%
df = pd.concat([messy_renamed, state_renamed, www_renamed, combined_masterfile_2_1_renamed]).reset_index(drop=True)
cols = df.columns.tolist()
if 'source_file' in cols:
    cols.insert(0, cols.pop(cols.index('source_file')))
    df = df[cols]
df.insert(1, "record_id", range(1, len(df) + 1))

# %%
df.columns.tolist()

# %%
from datetime import datetime
datetime_now = datetime.now().strftime("%Y-%m-%d")

df.to_csv(f"csv_outputs/merged_data_{datetime_now}.csv", index=False)
pd.Series(df["source_file"].unique()).to_csv(f"csv_outputs/merged_data_unique_source_files_{datetime_now}.csv", index=False)
